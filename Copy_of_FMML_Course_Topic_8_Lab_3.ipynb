# %% [markdown]
# <a href="https://colab.research.google.com/github/harikavelaga9999/FMML-LAB1/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 09:14:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   121MB/s    in 0.6s
#
# 2024-03-26 09:15:02 (121 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1973   1709.04695v1  We present a novel method to solve image analo...  stat
# 10425   1308.3506v1  Modeling the purposeful behavior of imperfect ...    cs
# 20858  1704.01049v1  We propose a simulated annealing algorithm spe...    cs
# 34214   1404.1982v1  Text is the main method of communicating infor...    cs
# 28488  1706.08336v1  We present a method to jointly refine the geom...    cs
# ...             ...                                                ...   ...
# 21745   1406.3824v3  Crowdsourcing is a popular paradigm for effect...  stat
# 10802   1405.2377v1  Much recent research has been conducted in the...  stat
# 29878  1710.10736v2  Finding faces in images is one of the most imp...    cs
# 7692   1802.08768v1  Recent work (Pennington et al, 2017) suggests ...  stat
# 31838   1102.0836v2  It is a challenging task to select correlated ...    cs
#
#                                                    title  year  \
# 1973   The Conditional Analogy GAN: Swapping Fashion ...  2017
# 10425  Computational Rationalization: The Inverse Equ...  2013
# 20858  A simulated annealing approach to optimal stor...  2017
# 34214  Aspect-Based Opinion Extraction from Customer ...  2014
# 28488  Semantically Informed Multiview Surface Refine...  2017
# ...                                                  ...   ...
# 21745  Spectral Methods meet EM: A Provably Optimal A...  2014
# 10802  A Hybrid Monte Carlo Architecture for Paramete...  2014
# 29878           Can you find a face in a HEVC bitstream?  2017
# 7692   Is Generator Conditioning Causally Related to ...  2018
# 31838  EigenNet: A Bayesian hybrid of generative and ...  2011
#
#                                                 keywords
# 1973   [generalize, correspond, therefore, conditiona...
# 10425  [purposeful, imperfect, observations, challeng...
# 20858  [simulated, annealing, algorithm, specifically...
# 34214  [communicating, information, opinionated, info...
# 28488  [segmentation, alternates, refinement, variati...
# ...                                                  ...
# 21745  [crowdsourcing, effectively, collecting, estim...
# 10802  [conducted, particularly, optimization, parame...
# 29878  [important, applications, biometrics, surveill...
# 7692   [controlling, distribution, important, conside...
# 31838  [challenging, correlated, variables, dimension...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1973     [generalize, correspond, therefore, conditiona...
# 10425    [purposeful, imperfect, observations, challeng...
# 20858    [simulated, annealing, algorithm, specifically...
# 34214    [communicating, information, opinionated, info...
# 28488    [segmentation, alternates, refinement, variati...
#                                ...
# 5396     [scientific, disciplines, structures, dimensio...
# 6901     [probabilistic, framework, determining, constr...
# 40068    [intensive, techniques, increasingly, importan...
# 21840    [modelling, metabolic, expression, application...
# 13404    [probabilistic, unstructured, statistical, dif...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4554 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0455c435-9e88-41b0-ba2b-f0fb23b77b0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0455c435-9e88-41b0-ba2b-f0fb23b77b0c")) {                    Plotly.newPlot(                        "0455c435-9e88-41b0-ba2b-f0fb23b77b0c",                        [{"x":["automatic","expensive","experimental","contributions","definition","therefore","supervised","following","architecture","technique","correspond","implicitly","improvements","interesting","generative","convincing","conditional","segmentation","applications","trainable","application","adversarial","generalize","convolutional","plausible","especially","employing","influence","competitive","introduce","myopically","imperfect","cooperative","approximately","restricted","observations","predicting","theoretic","challenging","computational","equilibrium","generalizing","situations","speculate","unobserved","techniques","accurately","principle","correlated","suggested","frequency","assignments","algorithm","constraints","necessarily","specifically","heuristics","simulated","retrieval","manufacturer","reduction","annealing","assignment","warehouse","clustering","experiments","positively","experiment","opinionated","decisions","information","ontologies","different","combining","promising","sequentially","summarize","extracting","processing","extraction","mechanism","purchased","framework","generates","enhancing","displayed","communicating","contribution","representative","similarity","purchasing","maximizes","calibrated","multiview","orientation","semantically","boundaries","variational","segmentations","geometric","smoothing","depending","evaluated","assumptions","influences","consistent","compatibility","minimization","consistency","reconstruction","interactions","refinement","simultaneously","demonstrate","alternates","synthetic","inference","compatible","baselines","predicted","significant","understanding","propagation","prediction","assistant","commercial","principled","detection","according","pipelined","ingredients","multitask","orthography","predictions","curriculum","delivered","including","sensitive","disadvantages","connected","scientific","neocortex","estimates","relatively","inhibitory","particular","inferring","challenge","relations","homogeneous","conflicting","understand","relationships","functionalities","developing","functional","organized","meaningful","population","anatomical","relational","important","processed","encodings","structure","bidirectionally","identifies","identification","syndromes","consistently","associations","appropriate","involving","concomitant","efficient","statistically","databases","pharmacovigilance","highlight","associated","verification","experience","identifying","positives","potential","attention","reliability","corresponding","registration","efficiency","superiority","accordingly","effective","averaging","available","introduced","percentage","fundamental","overlapping","robustness"],"y":[202,66,399,44,52,157,185,81,227,240,21,18,105,81,108,6,99,216,451,24,256,109,56,392,26,119,38,57,106,360,2,11,17,21,47,61,77,40,294,259,17,22,46,2,9,383,56,46,33,22,55,12,787,163,22,158,28,65,120,2,115,12,34,3,147,593,3,75,5,62,747,27,756,81,125,18,15,55,313,132,102,3,588,60,18,4,4,70,30,163,3,14,7,4,25,39,37,51,16,71,11,38,137,52,7,81,10,61,78,122,71,22,95,561,6,126,208,13,51,49,277,164,70,233,9,20,25,369,101,3,10,7,2,76,6,3,242,69,7,69,34,3,64,78,1,287,32,149,94,16,13,74,93,4,54,41,14,54,41,9,39,334,34,8,368,2,18,82,2,36,12,72,51,1,408,17,62,2,28,120,40,46,80,10,164,156,24,139,21,165,32,18,263,21,331,134,11,77,28,112],"type":"bar"},{"x":["automatic","expensive","experimental","contributions","definition","therefore","supervised","following","arch ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4554,), (4554, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>Results</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Logics</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3857965451055662);'>Knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.39517625231910947);'>Representation</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5438596491228069);'>Description</span> <span style=''>Logics</span> <span style=''>(DLs)</span> <span style=''>are</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3857965451055662);'>knowledge</span> <span style=''>based</span> <span style=''>systems</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.35789473684210527);'>represent</span> <span style=''>and</span> <span style=''>reason</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>terminological</span> <span style='background-color:rgba(0, 255, 0, 0.3857965451055662);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>domain</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.9024390243902439);'>semantically</span> <span style=''>well</span> <span style=''>defined</span> <span style=''>manner</span> <span style=''>In</span> <span style=''>this</span> <span style=''>thesis</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>results</span> <span style=''>and</span> <span style=''>give</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>DLs</span> <span style=''>that</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.33568904593639576);'>different</span> <span style=''>forms</span> <span style=''>of</span> <span style=''>counting</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>quantifiers</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>in</span> <span style=''>many</span> <span style=''>cases</span> <span style=''>adding</span> <span style=''>local</span> <span style=''>counting</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>qualifying</span> <span style=''>number</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictions</span> <span style=''>to</span> <span style=''>DLs</span> <span style=''>does</span> <span style=''>not</span> <span style=''>increase</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>inference</span> <span style=''>problems</span> <span style=''>even</span> <span style=''>if</span> <span style=''>binary</span> <span style=''>coding</span> <span style=''>of</span> <span style=''>numbers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>input</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>we</span> <span style=''>show< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>D2KE</span> <span style=''>From</span> <span style=''>Distance</span> <span style=''>to</span> <span style=''>Kernel</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embedding</span> <br/><br/><span style=''>For</span> <span style=''>many</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>settings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>inputs</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>or</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>a</span> <span style=''>distance</span> <span style=''>measure</span> <span style=''>between</span> <span style=''>inputs</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>than</span> <span style=''>a</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>However</span> <span style=''>most</span> <span style=''>standard</span> <span style=''>machine</span> <span style=''>models</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>inputs</span> <span style=''>with</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fmathcalX</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>R</span> <span style=''>based</span> <span style=''>solely</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>measure</span> <span style=''>dmathcalXtimesmathcalX</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rightarrow</span> <span style=''>R</span> <span style=''>between</span> <span style=''>inputs</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style=''>emphpositive</span> <span style=''>definite</span> <span style=''>kernels</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>subsumes</span> <span style=''>the</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>emphrepresentative</span> <span style=''>set</span> <span style=''>method</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>and</span> <span style=''>relates</span> <span style=''>to</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>emphdistance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substitution</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Katyusha</span> <span style=''>X</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Practical</span> <span style=''>Momentum</span> <span style=''>Method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.35584415584415574);'>Stochastic</span> <span style=''>Sum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>Nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>(ie</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>average</span> <span style=''>of</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>ones)</span> <span style=''>is</span> <span style=''>becoming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>is</span> <span style=''>the</span> <span style=''>core</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>machinery</span> <span style=''>for</span> <span style=''>PCA</span> <span style=''>SVD</span> <span style='background-color:rgba(255, 0, 0, 0.44444444444444453);'>regularized</span> <span style=''>Newtons</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerated</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style=''>more</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>provably</span> <span style=''>obtain</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerated</span> <span style='background-color:rgba(255, 0, 0, 0.35584415584415574);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>by</span> <span style=''>textitadding</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>line</span> <span style=''>to</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>SVRG</span> <span style=''>method</span> <span style=''>This</span> <span style=''>line</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>momentum</span> <span style=''>and</span> <span style=''>shows</span> <span style=''>how</span> <span style=''>to</span> <span style=''>directly</span> <span style=''>apply</span> <span style=''>momentum</span> <span style=''>to</span> <span style=''>the</span> <span style=''>finite</span> <span style=''>sum</span> <span style='background-color:rgba(255, 0, 0, 0.35584415584415574);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>nonconvex</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Architectures</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interaction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>based</span> <span style=''>Virtual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Screening</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>based</span> <span style=''>virtual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>fixed</span> <span style=''>sized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fingerprints</span> <span style=''>of</span> <span style=''>proteins</span> <span style=''>and</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>molecules</span> <span style=''>by</span> <span style=''>applying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>learnable</span> <span style=''>atom</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolution</span> <span style=''>and</span> <span style=''>softmax</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operations</span> <span style=''>to</span> <span style=''>each</span> <span style=''>compound</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separately</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fingerprints</span> <span style=''>are</span> <span style=''>further</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformed</span> <span style=''>non</span> <span style=''>linearly</span> <span style=''>their</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>and</span> <span style=''>used</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>binding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>insufficient</span> <span style=''>for</span> <span style=''>testing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>based</span> <span style=''>virtual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>utilize</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>dataset</span> <span style=''>which</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>based</span> <span style=''>on</span> <span style=''>DUD</span> <span style=''>E</span> <span style=''>and</span> <span style=''>P ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.11250898634076203)
# 	challenging (0.10567936736161035)
# 	representation (0.13515456506110712)
# 	segmentation (0.07764198418404025)
# 	experimental (0.1434219985621855)
# 	information (0.2685118619698059)
# 	detection (0.13263838964773544)
# 	different (0.2717469446441409)
# 	recognition (0.13803019410496045)
# 	convolutional (0.1409058231488138)
#
# Some Statistics words are:
# 	stochastic (0.12933597621407333)
# 	theoretical (0.1442021803766105)
# 	statistical (0.1491575817641229)
# 	estimation (0.17393458870168485)
# 	algorithm (0.3810703666997027)
# 	variables (0.1491575817641229)
# 	inference (0.19326065411298315)
# 	distribution (0.19573835480673935)
# 	dimensional (0.18929633300297324)
# 	regression (0.1759167492566898)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bb8339fe-e1b5-410e-b427-9ff5bde857fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb8339fe-e1b5-410e-b427-9ff5bde857fc")) {                    Plotly.newPlot(                        "bb8339fe-e1b5-410e-b427-9ff5bde857fc",                        [{"x":["automatic","expensive","experimental","contributions","definition","therefore","supervised","following","architecture","technique","correspond","implicitly","improvements","interesting","generative","convincing","conditional","segmentation","applications","trainable","application","adversarial","generalize","convolutional","plausible","especially","employing","influence","competitive","introduce","myopically","imperfect","cooperative","approximately","restricted","observations","predicting","theoretic","challenging","computational","equilibrium","generalizing","situations","speculate","unobserved","techniques","accurately","principle","correlated","suggested","frequency","assignments","algorithm","constraints","necessarily","specifically","heuristics","simulated","retrieval","manufacturer","reduction","annealing","assignment","warehouse","clustering","experiments","positively","experiment","opinionated","decisions","information","ontologies","different","combining","promising","sequentially","summarize","extracting","processing","extraction","mechanism","purchased","framework","generates","enhancing","displayed","communicating","contribution","representative","similarity","purchasing","maximizes","calibrated","multiview","orientation","semantically","boundaries","variational","segmentations","geometric","smoothing","depending","evaluated","assumptions","influences","consistent","compatibility","minimization","consistency","reconstruction","interactions","refinement","simultaneously","demonstrate","alternates","synthetic","inference","compatible","baselines","predicted","significant","understanding","propagation","prediction","assistant","commercial","principled","detection","according","pipelined","ingredients","multitask","orthography","predictions","curriculum","delivered","including","sensitive","disadvantages","connected","scientific","neocortex","estimates","relatively","inhibitory","particular","inferring","challenge","relations","homogeneous","conflicting","understand","relationships","functionalities","developing","functional","organized","meaningful","population","anatomical","relational","important","processed","encodings","structure","bidirectionally","identifies","identification","syndromes","consistently","associations","appropriate","involving","concomitant","efficient","statistically","databases","pharmacovigilance","highlight","associated","verification","experience","identifying","positives","potential","attention","reliability","corresponding","registration","efficiency","superiority","accordingly","effective","averaging","available","introduced","percentage","fundamental","overlapping","robustness","representing","representation","preferences","functions","guaranteed","necessity","distinction","modelling","investigates","condition","dependent","diagnostic","possibility","expressing","knowledge","distributions","expressed","distinguish","comparative","emphasized","possibilistic","representations","impossible","represents","impairment","establish","parametric","differences","computation","statistical","predictive","neuroimaging","regression","substantially","generated","cognitive","biomarker","chronological","individual","phenotype","deviations","volumetric","importance","classification","interfacing","approaches","weighting","estimation","algorithms","variability","performance","integrate","classifier","improvement","investigate","determine","thresh ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	biomarker
# 	ellipsoids
# 	semidefinite
# 	percolation
# 	retention
# 	disentanglement
# 	factorial
# 	thetastar
# 	proteomics
# 	intercept
# 	thermostats
# 	integrator
# 	thermostat
# 	cascading
# 	terabytes
# 	quadrature
# 	metabolite
# 	optimizers
# 	davenport
# 	nonasymptotic
# Some words which never appear in Statistics papers:
# 	myopically
# 	speculate
# 	manufacturer
# 	warehouse
# 	opinionated
# 	purchased
# 	purchasing
# 	assistant
# 	pipelined
# 	orthography
# 	neocortex
# 	functionalities
# 	encodings
# 	bidirectionally
# 	possibilistic
# 	microblogging
# 	evolvability
# 	modularized
# 	interleaved
# 	geotagging

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0888984987953295e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
